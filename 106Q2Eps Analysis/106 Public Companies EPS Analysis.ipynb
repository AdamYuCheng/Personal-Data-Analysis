# %% [markdown]
# # 106年Q2 上市公司各產業EPS統計資訊分析

# %% [markdown]
# **欲探詢的問題：** 那一些產業/上市公司的獲利創況是值得關注的
#
# *藉由產業別與個別的公司獲利狀況去篩選可行的投資標的*
#
# * 資料來源: 政府資料開放平台 https://data.gov.tw
#
# * 資料項目: 上市公司各產業EPS統計資訊
#
# * 資料時間：106年Q2

# %% [markdown]
# ****
# ## 1. 引入各項Pandas設定及導入資料

# %%
#import library
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %pylab inline
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('precision',3)
pd.options.display.float_format = '{:,.4f}'.format
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#import data
path = 'C:/Users/AdamChang/Documents/Python Scripts/data/PFD Data/上市公司各產業EPS統計資訊.csv'
df = pd.read_csv(path, encoding='big5hkscs', index_col=0, skiprows=1, 
                 names=['Code','Company','Industry','Eps','Denomination','OperationIncome',
                       'OperationProfit','OtherIncome','NetProfitAfterTax'])

# %% [markdown]
# ****
# # **2.檢視Data Summary**

# %% [markdown]
# 先檢視各個Column的資料概況

# %%
df.describe()
# Out:
#            Eps    OperationIncome  NetProfitAfterTax    Profit
# count 884.0000           884.0000           884.0000  884.0000
# mean    1.0316    14,630,452.4016       903,398.4819   -0.2148
# std     2.8887    75,913,939.6010     5,912,957.9459    7.0936
# min    -5.1400            16.0000    -3,983,116.0000 -210.2500
# 25%     0.0600     1,056,085.5000         9,019.0000    0.0058
# 50%     0.5700     2,479,770.5000       121,794.5000    0.0433
# 75%     1.5525     7,166,839.7500       431,998.2500    0.0988
# max    71.5600 1,897,456,321.0000   153,891,560.0000    7.8216

# %% [markdown]
# ***
# # **3.依照公司的Eps, 營業收益, 稅後淨利篩選各指標的前10大上市公司**

# %%
#檢視前10大Eps的上市公司
#view top 10 eps companies
dfEps = df.sort_values(by='Eps', ascending=False)
dfEps.head(10)
# Out:
#                   Company Industry     Eps                  Denomination  \
# Code
# 3008           大立光電股份有限公司      光電業 71.5600  新台幣                 10.0000元
# 2227         裕隆日產汽車股份有限公司     汽車工業 10.9100  新台幣                 10.0000元
# 3040           遠見科技股份有限公司       其他 10.8200  新台幣                 10.0000元
# 6415            矽力杰股份有限公司     半導體業 10.2600  新台幣                 10.0000元
# 2207           和泰汽車股份有限公司     汽車工業  9.8300  新台幣                 10.0000元
# 1590              亞德客國際集團     電機機械  9.0100  新台幣                 10.0000元
# 6409           旭隼科技股份有限公司    其他電子業  8.6100  新台幣                 10.0000元
# 8070           長華電材股份有限公司    電子通路業  8.3400  新台幣                 10.0000元
# 2474           可成科技股份有限公司    其他電子業  8.0300  新台幣                 10.0000元
# 6456  GIS Holding Limited      光電業  7.6400  新台幣                 10.0000元
#
#       OperationIncome OperationProfit OtherIncome  NetProfitAfterTax
# Code
# 3008         22120996        13252284     -637509            9598457
# 2227         18718262         1344262     2597594            3272218
# 3040            87124           13861      723883             681452
# 6415          4015173          877718       15444             866707
# 2207         91730282              --          --            6089445
# 1590          6409430         2028494      105157            1612108
# 6409          4677247          886613      -90696             672081
# 8070          6390263          433574      335006             585587
# 2474         33080089        12400695    -2351791            6199915
# 6456         41586659         3058987       93872            2356600

# %%
#檢視前10大營業收益的上市公司
#top 10 operation income company
dfOI = df.sort_values(by='OperationIncome', ascending=False)
dfOI.head(10)
# Out:
#              Company  Industry    Eps                  Denomination  \
# Code
# 2317    鴻海精密工業股份有限公司     其他電子業 2.6600  新台幣                 10.0000元
# 4938    和碩聯合科技股份有限公司  電腦及週邊設備業 2.8400  新台幣                 10.0000元
# 2382      廣達電腦股份有限公司  電腦及週邊設備業 1.7600  新台幣                 10.0000元
# 2330  台灣積體電路製造股份有限公司      半導體業 5.9400  新台幣                 10.0000元
# 2324    仁寶電腦工業股份有限公司  電腦及週邊設備業 0.3100  新台幣                 10.0000元
# 3231      緯創資通股份有限公司  電腦及週邊設備業 0.5200  新台幣                 10.0000元
# 6505      台塑石化股份有限公司     油電燃氣業 3.6400  新台幣                 10.0000元
# 3702   大聯大投資控股股份有限公司     電子通路業 2.0900  新台幣                 10.0000元
# 2356       英業達股份有限公司  電腦及週邊設備業 0.7300  新台幣                 10.0000元
# 2357      華碩電腦股份有限公司  電腦及週邊設備業 7.6200  新台幣                 10.0000元
#
#       OperationIncome OperationProfit OtherIncome  NetProfitAfterTax
# Code
# 2317       1897456321        61441120      648733           44126222
# 4938        479379730         9963099        9738            7838887
# 2382        463280886         8658357      867200            6869701
# 2330        447769612       178607791     5332175          153891560
# 2324        401207947         3841614    -1292130            1525380
# 3231        362246296         1924871      117435            1534638
# 6505        303403322        42742733     -731048           34673023
# 3702        247381962         4602987     -131119            3674350
# 2356        210874919         3728754     -536324            2082841
# 2357        205539421         5929667     1426685            5823518

# %%
#檢視前10大稅後獲利率的上市公司
#top 10 Profit Rate company
df['Profit'] = df['NetProfitAfterTax']/df['OperationIncome']
dfProfit = df.sort_values(by='Profit', ascending=False)
dfProfit.head(10)
# Out:
#             Company Industry     Eps                  Denomination  \
# Code
# 3040     遠見科技股份有限公司       其他 10.8200  新台幣                 10.0000元
# 1235     興泰實業股份有限公司     食品工業  1.7600  新台幣                 10.0000元
# 2706  第一華僑大飯店股份有限公司     觀光事業  0.5600  新台幣                 10.0000元
# 2701     萬華企業股份有限公司     觀光事業  0.4500  新台幣                 10.0000元
# 2536     宏普建設股份有限公司     建材營造  0.3600  新台幣                 10.0000元
# 8926   台灣汽電共生股份有限公司    油電燃氣業  0.7300  新台幣                 10.0000元
# 2514   龍邦國際興業股份有限公司       其他  1.5900  新台幣                 10.0000元
# 2820   中華票券金融股份有限公司    金融保險業  0.4900  新台幣                 10.0000元
# 2809   京城商業銀行股份有限公司    金融保險業  2.4000  新台幣                 10.0000元
# 1437   勤益投資控股股份有限公司     半導體業  0.9400  新台幣                 10.0000元
#
#       OperationIncome OperationProfit OtherIncome  NetProfitAfterTax  Profit
# Code
# 3040            87124           13861      723883             681452  7.8216
# 1235            24866          -19909      158752             103160  4.1486
# 2706           165011          102906      198690             254101  1.5399
# 2701           191535           83981      138412             188520  0.9843
# 2536           126358           -7222      155429             120738  0.9555
# 8926           499442           30205      417001             427751  0.8565
# 2514          1101880          945809      -27414             790021  0.7170
# 2820          1018098              --          --             658188  0.6465
# 2809          4306485              --          --            2751471  0.6389
# 1437           299308          165385       45150             182426  0.6095

# %%
#檢視基本統計資訊
#check summary of the data
df.describe()
# Out:
#            Eps    OperationIncome  NetProfitAfterTax    Profit
# count 884.0000           884.0000           884.0000  884.0000
# mean    1.0316    14,630,452.4016       903,398.4819   -0.2148
# std     2.8887    75,913,939.6010     5,912,957.9459    7.0936
# min    -5.1400            16.0000    -3,983,116.0000 -210.2500
# 25%     0.0600     1,056,085.5000         9,019.0000    0.0058
# 50%     0.5700     2,479,770.5000       121,794.5000    0.0433
# 75%     1.5525     7,166,839.7500       431,998.2500    0.0988
# max    71.5600 1,897,456,321.0000   153,891,560.0000    7.8216

# %% [markdown]
# ****
# # 4.依照產業類別做篩選，篩選出高Eps與獲利的上市公司

# %%
from bokeh.io import output_notebook, show
from bokeh.charts import Histogram

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="44ede80c-f776-4e72-ab2f-bd7028ee2666">Loading BokehJS ...</span>
#     </div>

# %%
#檢視上市公司的獲利分布
#View the Eps distribution
EpsHist = Histogram(df, values='Eps')
show(EpsHist)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="520633d5-dd70-461e-a191-c5181fcf64dc"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#520633d5-dd70-461e-a191-c5181fcf64dc").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("520633d5-dd70-461e-a191-c5181fcf64dc");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '520633d5-dd70-461e-a191-c5181fcf64dc' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"37a2e5df-8be2-4cd0-848b-d309da8b784a":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e70b6ed5-6011-4b50-b5eb-0b6f8ef81f88","type":"Rect"},{"attributes":{"callback":null,"column_names":["y","label","line_color","height","color","x","width","line_alpha","fill_alpha"],"data":{"chart_index":["(46.1, 46.4]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(46.1, 46.4]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.310526315789474],"x":["46.25"],"y":[0.0]}},"id":"5ce1e343-c855-4993-af05-9bfaada15c85","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"e5a6b124-a14f-4816-b220-40729c259dbf","type":"ColumnDataSource"},"glyph":{"id":"b8260178-9810-4055-ae6d-885cd83de422","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"06b13b5a-bca0-4265-8696-2e5685efa30e","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"e2ebf592-6008-4be0-9c50-14c5a042ce06","type":"ColumnDataSource"},"glyph":{"id":"833a9cac-db6f-4e8d-bcf6-fc3e0b78055f","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"dad8a8c3-3588-4f65-ac63-cdfd554d9ed1","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a89a770f-7c46-404b-80a5-876575c62049","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d7c27a26-aaee-4172-a5c4-cce54a74da3d","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"30ed17d6-f1ed-4bdf-bc8c-f24fc433e241","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d2498d68-8e57-4d16-9272-4117cd10b078","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ccbe7af6-3ad8-4708-b0b1-5e566c7efbc2","type":"Rect"},{"attributes":{"data_source":{"id":"9fbe4732-9b5e-43d0-ae1d-00dba5b745f6","type":"ColumnDataSource"},"glyph":{"id":"234c1762-9ffa-433d-ad60-bbed76680de8","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"0cca2c17-8f7d-469e-aaa9-8fd4eff9e559","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y","label","line_color","height","color","x","width","line_alpha","fill_alpha"],"data":{"chart_index":["(58.2, 58.5]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(58.2, 58.5]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.310526315789474],"x":["58.35"],"y":[0.0]}},"id":"93bc7cf1-ae2e-48ed-844f-c5c305320671","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"fb18acfb-74ed-476d-b51b-b5a7b7af5edc","type":"ColumnDataSource"},"glyph":{"id":"88c221d3-2e00-40d6-ad07-8d3445fdbb17","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"d56fed11-c478-41e5-8def-929ce9e42990","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y","label","line_color ...

# %%
#檢視上市公司營收狀況分布
#View the distribution of Operation Income
OperationIncomeHist = Histogram(df, values='OperationIncome')
show(OperationIncomeHist)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="4ffc267c-b9c9-4a21-8109-ca5a38242f39"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#4ffc267c-b9c9-4a21-8109-ca5a38242f39").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4ffc267c-b9c9-4a21-8109-ca5a38242f39");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4ffc267c-b9c9-4a21-8109-ca5a38242f39' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"d740f7f6-cde8-4519-bbc4-30e7e204c951":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"db62fb3e-f4dd-49a2-99f1-ce7e35cd83d1","type":"Rect"},{"attributes":{"callback":null,"column_names":["y","label","line_color","height","color","x","width","line_alpha","fill_alpha"],"data":{"chart_index":["(1660751510.3, 1662024116.8]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(1660751510.3, 1662024116.8]"],"line_alpha":[1.0],"line_color":["black"],"width":[1272606.5090544224],"x":["1661387813.55"],"y":[0.0]}},"id":"c6365039-b93f-4c16-a058-494a9c3f4d25","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["y","label","line_color","height","color","x","width","line_alpha","fill_alpha"],"data":{"chart_index":["(1222974871.2, 1224247477.7]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(1222974871.2, 1224247477.7]"],"line_alpha":[1.0],"line_color":["black"],"width":[1272606.5090544224],"x":["1223611174.45"],"y":[0.0]}},"id":"6187c7d4-593b-4a54-af9d-08c54e40684b","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"a9f40af5-bcb7-4d43-b301-1086b470040f","type":"ColumnDataSource"},"glyph":{"id":"cd878733-3afe-4117-8c57-eddf46298b01","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"7191ba35-f7e4-4b7d-983d-a5525becf6c0","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"c701977e-5201-4525-ac3b-1ea60560a370","type":"ColumnDataSource"},"glyph":{"id":"b6cb3aa0-1976-42f3-b176-af88c4bb20ad","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"e1492019-a316-447c-94b4-3c11c199d145","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y","label","line_color","height","color","x","width","line_alpha","fill_alpha"],"data":{"chart_index":["(873008081.2, 874280687.7]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(873008081.2, 874280687.7]"],"line_alpha":[1.0],"line_color":["black"],"width":[1272606.5090543032],"x":["873644384.45"],"y":[0.0]}},"id":"be35dfb6-5ea8-41b6-8884-653974c7863e","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["y","label","line_color","height","color","x","width","line_alpha","fill_alpha"],"data":{"chart_index":["(370328510.1, 371601116.6]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(370328510.1, 371601116.6]"],"line_alpha":[1.0],"line_color":["black"],"width":[1272606.5090543628],"x":["370964813.35"],"y":[0.0]}},"id":"98001625-05e7-4a47-9159-0e4795371868","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b7ac74a4-1fc3-4522-99e7-ccaa2916d431","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3024b2e1-3ffb-422f-99ca-0cd133b47a5b","type":"Rect"},{"attributes":{"callback":null,"column_names":["y","label","line_color","height","color","x","width","line_alpha","fill_alpha"],"data":{"chart_index":["(853918983.6, 855191590.1]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(853918983.6, 855191590.1]"],"line_alpha":[1.0],"line_color":["black"],"width":[1272606.5090544224],"x":["854555286.85"],"y":[0.0]}},"id":"807b3238-a1ca-4a21-b44d-2bf1df999eea","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["y","label","line_color","height","color","x","width","line_alpha","fill_alpha"],"data":{"chart_inde ...

# %%
#檢視ouliar的資料
#find the outliar
df[df.Eps>20]
# Out:
#          Company Industry     Eps                  Denomination  \
# Code
# 3008  大立光電股份有限公司      光電業 71.5600  新台幣                 10.0000元
#
#       OperationIncome OperationProfit OtherIncome  NetProfitAfterTax  Profit
# Code
# 3008         22120996        13252284     -637509            9598457  0.4339

# %%
# 3008高獲利，但也高門檻，先將他從投資選項中剃除
# 3008 have high Eps, but also high stock price. Remove it from the data
dfDelOutl = df.drop(df[df.Eps>20].index)

#再度檢視Eps分布狀況
#View the distribution of Eps again.
EpsHist2 = Histogram(dfDelOutl, values='Eps')
show(EpsHist2)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="80588c17-f322-4450-b1a0-110ce2d55b6e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#80588c17-f322-4450-b1a0-110ce2d55b6e").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("80588c17-f322-4450-b1a0-110ce2d55b6e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '80588c17-f322-4450-b1a0-110ce2d55b6e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"a8242d0b-57b5-425d-8464-e97e4e707d43":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["y","label","line_color","height","color","x","width","line_alpha","fill_alpha"],"data":{"chart_index":["(-2.7, -2.4]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[1.0],"label":["(-2.7, -2.4]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.30865384615384617],"x":["-2.55"],"y":[0.5]}},"id":"58459bd6-3215-4e06-abb8-5954e446a650","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["y","label","line_color","height","color","x","width","line_alpha","fill_alpha"],"data":{"chart_index":["(5.7, 6.0]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[3.0],"label":["(5.7, 6.0]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.3086538461538453],"x":["5.85"],"y":[1.5]}},"id":"6e1928ea-30a3-4006-bd79-87f1e26c33b0","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d4d71308-f51f-45f4-89bc-988fbccca5d1","type":"Rect"},{"attributes":{"data_source":{"id":"76ca3fd2-4e3f-4385-afeb-61122f81c590","type":"ColumnDataSource"},"glyph":{"id":"bfca9b84-c53e-447e-b715-518abcac6f05","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"8cc49193-1d55-4e79-9481-71988cfb774e","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"f58f899c-2623-4070-b5b3-d084a63e82af","type":"ColumnDataSource"},"glyph":{"id":"cda913a4-e11c-41e0-a9c0-98556c5d3584","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"32275130-cd9d-421b-8c08-2cb913a987de","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y","label","line_color","height","color","x","width","line_alpha","fill_alpha"],"data":{"chart_index":["(3.2, 3.5]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[15.0],"label":["(3.2, 3.5]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.3086538461538453],"x":["3.35"],"y":[7.5]}},"id":"e768510e-5bf1-49e1-8046-0b5d0e970a00","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"07959c4d-37c0-4a47-8697-aff9ac244444","type":"ColumnDataSource"},"glyph":{"id":"c927849e-e4b0-4294-bc65-84a2ef8fd066","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"8b226eb5-3df4-4fc6-9345-76f84c72078f","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y","label","line_color","height","color","x","width","line_alpha","fill_alpha"],"data":{"chart_index":["(2.6, 2.9]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[24.0],"label":["(2.6, 2.9]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.30865384615384617],"x":["2.75"],"y":[12.0]}},"id":"74758f59-7a6a-4664-acac-eaf7e0469ce2","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ab579276-51c3-4449-a97f-8f7b43e99bc9","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6d2df4c7-9924-40c3-994d-5f10537e10b1","type":"Rect"},{"attributes":{"callback":null,"column_names":["y","label","line_color","height","color","x","width","line_alpha","fill_alpha"],"data":{"chart_index":["(-3.3, -3.0]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(-3.3, -3.0]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.30865384615384617],"x":["-3.15"],"y":[0.0]}},"id":"7ae66974-0aa0-4d0c-a91a-f32ecddf904f","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field ...

# %%
IndsGroup = dfDelOutl.groupby('Industry')
IndsGroup

# %%
#將各行業的Eps, 營業收入, 稅後收入加總，檢視各行業的獲利狀況，評估賺錢的行業為何
#黃色底為最大值的行業

IndsGroupEpsSum = IndsGroup.agg(np.sum)
IndsGroupEpsSum.sort_values(by='Eps',ascending=False).style.highlight_max(axis=0)
# Out:
# <style  type="text/css" >
#     #T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow0_col0 {
#             background-color:  yellow;
#         }    #T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow0_col3 {
#             background-color:  yellow;
#         }    #T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow1_col2 {
#             background-color:  yellow;
#         }    #T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow4_col1 {
#             background-color:  yellow;
#         }</style>
# <table id="T_d89631d4_9866_11e7_aae5_a434d9ea9dda" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Eps</th>
#         <th class="col_heading level0 col1" >OperationIncome</th>
#         <th class="col_heading level0 col2" >NetProfitAfterTax</th>
#         <th class="col_heading level0 col3" >Profit</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Industry</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_d89631d4_9866_11e7_aae5_a434d9ea9dda" class="row_heading level0 row0" >其他</th>
#         <td id="T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow0_col0" class="data row0 col0" >107</td>
#         <td id="T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow0_col1" class="data row0 col1" >408058699</td>
#         <td id="T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow0_col2" class="data row0 col2" >37258538</td>
#         <td id="T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow0_col3" class="data row0 col3" >14.2</td>
#     </tr>    <tr>
#         <th id="T_d89631d4_9866_11e7_aae5_a434d9ea9dda" class="row_heading level0 row1" >半導體業</th>
#         <td id="T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow1_col0" class="data row1 col0" >92.7</td>
#         <td id="T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow1_col1" class="data row1 col1" >1121309305</td>
#         <td id="T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow1_col2" class="data row1 col2" >213421612</td>
#         <td id="T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow1_col3" class="data row1 col3" >1.86</td>
#     </tr>    <tr>
#         <th id="T_d89631d4_9866_11e7_aae5_a434d9ea9dda" class="row_heading level0 row2" >電子零組件業</th>
#         <td id="T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow2_col0" class="data row2 col0" >84.8</td>
#         <td id="T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow2_col1" class="data row2 col1" >643215801</td>
#         <td id="T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow2_col2" class="data row2 col2" >28937392</td>
#         <td id="T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow2_col3" class="data row2 col3" >1.82</td>
#     </tr>    <tr>
#         <th id="T_d89631d4_9866_11e7_aae5_a434d9ea9dda" class="row_heading level0 row3" >電機機械</th>
#         <td id="T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow3_col0" class="data row3 col0" >80</td>
#         <td id="T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow3_col1" class="data row3 col1" >212609549</td>
#         <td id="T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow3_col2" class="data row3 col2" >15073454</td>
#         <td id="T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow3_col3" class="data row3 col3" >3.7</td>
#     </tr>    <tr>
#         <th id="T_d89631d4_9866_11e7_aae5_a434d9ea9dda" class="row_heading level0 row4" >電腦及週邊設備業</th>
#         <td id="T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow4_col0" class="data row4 col0" >58.3</td>
#         <td id="T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow4_col1" class="data row4 col1" >2667716295</td>
#         <td id="T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow4_col2" class="data row4 col2" >45473504</td>
#         <td id="T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow4_col3" class="data row4 col3" >-5.92</td>
#     </tr>    <tr>
#         <th id="T_d89631d4_9866_11e7_aae5_a434d9ea9dda" class="row_heading level0 row5" >其他電子業</th>
#         <td id="T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow5_col0" class="data row5 col0" >48</td>
#         <td id="T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow5_col1" class="data row5 col1" >2121122903</td>
#         <td id="T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow5_col2" class="data row5 col2" >59544368</td>
#         <td id="T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow5_col3" class="data row5 col3" >0.893</td>
#     </tr>    <tr>
#         <th id="T_d89631d4_9866_11e7_aae5_a434d9ea9dda" class="row_heading level0 row6" >汽車工業</th>
#         <td id="T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow6_col0" class="data row6 col0" >34.1</td>
#         <td id="T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow6_col1" class="data row6 col1" >210624271</td>
#         <td id="T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow6_col2" class="data row6 col2" >14769831</td>
#         <td id="T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow6_col3" class="data row6 col3" >0.645</td>
#     </tr>    <tr>
#         <th id="T_d89631d4_9866_11e7_aae5_a434d9ea9dda" class="row_heading level0 row7" >電子通路業</th>
#         <td id="T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow7_col0" class="data row7 col0" >29.4</td>
#         <td id="T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow7_col1" class="data row7 col1" >714259769</td>
#         <td id="T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow7_col2" class="data row7 col2" >10893026</td>
#         <td id="T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow7_col3" class="data row7 col3" >0.303</td>
#     </tr>    <tr>
#         <th id="T_d89631d4_9866_11e7_aae5_a434d9ea9dda" class="row_heading level0 row8" >通信網路業</th>
#         <td id="T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow8_col0" class="data row8 col0" >29</td>
#         <td id="T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow8_col1" class="data row8 col1" >431256614</td>
#         <td id="T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow8_col2" class="data row8 col2" >33908334</td>
#         <td id="T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow8_col3" class="data row8 col3" >1.27</td>
#     </tr>    <tr>
#         <th id="T_d89631d4_9866_11e7_aae5_a434d9ea9dda" class="row_heading level0 row9" >建材營造</th>
#         <td id="T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow9_col0" class="data row9 col0" >28.9</td>
#         <td id="T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow9_col1" class="data row9 col1" >117554303</td>
#         <td id="T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow9_col2" class="data row9 col2" >12242161</td>
#         <td id="T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow9_col3" class="data row9 col3" >-213</td>
#     </tr>    <tr>
#         <th id="T_d89631d4_9866_11e7_aae5_a434d9ea9dda" class="row_heading level0 row10" >塑膠工業</th>
#         <td id="T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow10_col0" class="data row10 col0" >26</td>
#         <td id="T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow10_col1" class="data row10 col1" >565559360</td>
#         <td id="T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow10_col2" class="data row10 col2" >73778512</td>
#         <td id="T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow10_col3" class="data row10 col3" >1.92</td>
#     </tr>    <tr>
#         <th id="T_d89631d4_9866_11e7_aae5_a434d9ea9dda" class="row_heading level0 row11" >生技醫療業</th>
#         <td id="T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow11_col0" class="data row11 col0" >25.8</td>
#         <td id="T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow11_col1" class="data row11 col1" >47537368</td>
#         <td id="T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow11_col2" class="data row11 col2" >2497733</td>
#         <td id="T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow11_col3" class="data row11 col3" >-5.82</td>
#     </tr>    <tr>
#         <th id="T_d89631d4_9866_11e7_aae5_a434d9ea9dda" class="row_heading level0 row12" >貿易百貨</th>
#         <td id="T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow12_col0" class="data row12 col0" >25.2</td>
#         <td id="T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow12_col1" class="data row12 col1" >322463110</td>
#         <td id="T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow12_col2" class="data row12 col2" >13880183</td>
#         <td id="T_d89631d4_9866_11e7_aae5_a434d9ea9ddarow12_col3" class="data row12 col3" >1.49</td>
#     </tr>    <tr>
#         <th id="T_d89631d4_9866_11e7_aae5_a434d9e

# %%
#將各行業的Eps, 營業收入, 稅後收入取平均值，看各行業內企業的獲利狀況，評估哪個行業的平均概況較好
IndsGroupEpsMean = IndsGroup.agg(np.mean)
IndsGroupEpsMean.sort_values(by='Eps',ascending=False).style.highlight_max(axis=0)
# Out:
# <style  type="text/css" >
#     #T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow0_col0 {
#             background-color:  yellow;
#         }    #T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow3_col2 {
#             background-color:  yellow;
#         }    #T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow6_col1 {
#             background-color:  yellow;
#         }    #T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow17_col3 {
#             background-color:  yellow;
#         }</style>
# <table id="T_d89cecec_9866_11e7_a9a8_a434d9ea9dda" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Eps</th>
#         <th class="col_heading level0 col1" >OperationIncome</th>
#         <th class="col_heading level0 col2" >NetProfitAfterTax</th>
#         <th class="col_heading level0 col3" >Profit</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Industry</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_d89cecec_9866_11e7_a9a8_a434d9ea9dda" class="row_heading level0 row0" >汽車工業</th>
#         <td id="T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow0_col0" class="data row0 col0" >4.26</td>
#         <td id="T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow0_col1" class="data row0 col1" >2.63e+07</td>
#         <td id="T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow0_col2" class="data row0 col2" >1.85e+06</td>
#         <td id="T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow0_col3" class="data row0 col3" >0.0806</td>
#     </tr>    <tr>
#         <th id="T_d89cecec_9866_11e7_a9a8_a434d9ea9dda" class="row_heading level0 row1" >其他</th>
#         <td id="T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow1_col0" class="data row1 col0" >1.85</td>
#         <td id="T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow1_col1" class="data row1 col1" >7.04e+06</td>
#         <td id="T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow1_col2" class="data row1 col2" >6.42e+05</td>
#         <td id="T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow1_col3" class="data row1 col3" >0.244</td>
#     </tr>    <tr>
#         <th id="T_d89cecec_9866_11e7_a9a8_a434d9ea9dda" class="row_heading level0 row2" >觀光事業</th>
#         <td id="T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow2_col0" class="data row2 col0" >1.52</td>
#         <td id="T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow2_col1" class="data row2 col1" >2.84e+06</td>
#         <td id="T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow2_col2" class="data row2 col2" >2.01e+05</td>
#         <td id="T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow2_col3" class="data row2 col3" >0.212</td>
#     </tr>    <tr>
#         <th id="T_d89cecec_9866_11e7_a9a8_a434d9ea9dda" class="row_heading level0 row3" >油電燃氣業</th>
#         <td id="T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow3_col0" class="data row3 col0" >1.51</td>
#         <td id="T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow3_col1" class="data row3 col1" >4.08e+07</td>
#         <td id="T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow3_col2" class="data row3 col2" >4.57e+06</td>
#         <td id="T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow3_col3" class="data row3 col3" >0.211</td>
#     </tr>    <tr>
#         <th id="T_d89cecec_9866_11e7_a9a8_a434d9ea9dda" class="row_heading level0 row4" >電機機械</th>
#         <td id="T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow4_col0" class="data row4 col0" >1.46</td>
#         <td id="T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow4_col1" class="data row4 col1" >3.87e+06</td>
#         <td id="T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow4_col2" class="data row4 col2" >2.74e+05</td>
#         <td id="T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow4_col3" class="data row4 col3" >0.0673</td>
#     </tr>    <tr>
#         <th id="T_d89cecec_9866_11e7_a9a8_a434d9ea9dda" class="row_heading level0 row5" >電子通路業</th>
#         <td id="T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow5_col0" class="data row5 col0" >1.4</td>
#         <td id="T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow5_col1" class="data row5 col1" >3.4e+07</td>
#         <td id="T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow5_col2" class="data row5 col2" >5.19e+05</td>
#         <td id="T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow5_col3" class="data row5 col3" >0.0144</td>
#     </tr>    <tr>
#         <th id="T_d89cecec_9866_11e7_a9a8_a434d9ea9dda" class="row_heading level0 row6" >其他電子業</th>
#         <td id="T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow6_col0" class="data row6 col0" >1.37</td>
#         <td id="T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow6_col1" class="data row6 col1" >6.06e+07</td>
#         <td id="T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow6_col2" class="data row6 col2" >1.7e+06</td>
#         <td id="T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow6_col3" class="data row6 col3" >0.0255</td>
#     </tr>    <tr>
#         <th id="T_d89cecec_9866_11e7_a9a8_a434d9ea9dda" class="row_heading level0 row7" >半導體業</th>
#         <td id="T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow7_col0" class="data row7 col0" >1.29</td>
#         <td id="T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow7_col1" class="data row7 col1" >1.56e+07</td>
#         <td id="T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow7_col2" class="data row7 col2" >2.96e+06</td>
#         <td id="T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow7_col3" class="data row7 col3" >0.0258</td>
#     </tr>    <tr>
#         <th id="T_d89cecec_9866_11e7_a9a8_a434d9ea9dda" class="row_heading level0 row8" >貿易百貨</th>
#         <td id="T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow8_col0" class="data row8 col0" >1.26</td>
#         <td id="T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow8_col1" class="data row8 col1" >1.61e+07</td>
#         <td id="T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow8_col2" class="data row8 col2" >6.94e+05</td>
#         <td id="T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow8_col3" class="data row8 col3" >0.0743</td>
#     </tr>    <tr>
#         <th id="T_d89cecec_9866_11e7_a9a8_a434d9ea9dda" class="row_heading level0 row9" >塑膠工業</th>
#         <td id="T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow9_col0" class="data row9 col0" >1.13</td>
#         <td id="T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow9_col1" class="data row9 col1" >2.46e+07</td>
#         <td id="T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow9_col2" class="data row9 col2" >3.21e+06</td>
#         <td id="T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow9_col3" class="data row9 col3" >0.0834</td>
#     </tr>    <tr>
#         <th id="T_d89cecec_9866_11e7_a9a8_a434d9ea9dda" class="row_heading level0 row10" >食品工業</th>
#         <td id="T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow10_col0" class="data row10 col0" >1.07</td>
#         <td id="T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow10_col1" class="data row10 col1" >1.43e+07</td>
#         <td id="T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow10_col2" class="data row10 col2" >9.01e+05</td>
#         <td id="T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow10_col3" class="data row10 col3" >0.248</td>
#     </tr>    <tr>
#         <th id="T_d89cecec_9866_11e7_a9a8_a434d9ea9dda" class="row_heading level0 row11" >電腦及週邊設備業</th>
#         <td id="T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow11_col0" class="data row11 col0" >1</td>
#         <td id="T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow11_col1" class="data row11 col1" >4.6e+07</td>
#         <td id="T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow11_col2" class="data row11 col2" >7.84e+05</td>
#         <td id="T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow11_col3" class="data row11 col3" >-0.102</td>
#     </tr>    <tr>
#         <th id="T_d89cecec_9866_11e7_a9a8_a434d9ea9dda" class="row_heading level0 row12" >資訊服務業</th>
#         <td id="T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow12_col0" class="data row12 col0" >0.973</td>
#         <td id="T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow12_col1" class="data row12 col1" >2.06e+06</td>
#         <td id="T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow12_col2" class="data row12 col2" >1.06e+05</td>
#         <td id="T_d89cecec_9866_11e7_a9a8_a434d9ea9ddarow12_col3" class="data row12 col3" >0.044</td>
#     </tr>    <tr>
#         <th id="T_d89cecec_9866_11e7_a9a8_a43

# %%
#將各行業Eps平均值與加總彙整比較
IndsEpsSum = IndsGroupEpsSum['Eps']
IndsEpsMean = IndsGroupEpsMean['Eps']
IndEps = pd.DataFrame({'EpsSum':IndsEpsSum,
                      'EpsMean':IndsEpsMean})
IndEps['Percent'] = IndEps['EpsMean']/IndEps['EpsSum']
IndEps.sort_values(by='EpsSum', ascending=False).style.highlight_max(axis=0)
# Out:
# <style  type="text/css" >
#     #T_d8adc19a_9866_11e7_81dd_a434d9ea9ddarow0_col1 {
#             background-color:  yellow;
#         }    #T_d8adc19a_9866_11e7_81dd_a434d9ea9ddarow6_col0 {
#             background-color:  yellow;
#         }    #T_d8adc19a_9866_11e7_81dd_a434d9ea9ddarow26_col2 {
#             background-color:  yellow;
#         }</style>
# <table id="T_d8adc19a_9866_11e7_81dd_a434d9ea9dda" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >EpsMean</th>
#         <th class="col_heading level0 col1" >EpsSum</th>
#         <th class="col_heading level0 col2" >Percent</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Industry</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_d8adc19a_9866_11e7_81dd_a434d9ea9dda" class="row_heading level0 row0" >其他</th>
#         <td id="T_d8adc19a_9866_11e7_81dd_a434d9ea9ddarow0_col0" class="data row0 col0" >1.85</td>
#         <td id="T_d8adc19a_9866_11e7_81dd_a434d9ea9ddarow0_col1" class="data row0 col1" >107</td>
#         <td id="T_d8adc19a_9866_11e7_81dd_a434d9ea9ddarow0_col2" class="data row0 col2" >0.0172</td>
#     </tr>    <tr>
#         <th id="T_d8adc19a_9866_11e7_81dd_a434d9ea9dda" class="row_heading level0 row1" >半導體業</th>
#         <td id="T_d8adc19a_9866_11e7_81dd_a434d9ea9ddarow1_col0" class="data row1 col0" >1.29</td>
#         <td id="T_d8adc19a_9866_11e7_81dd_a434d9ea9ddarow1_col1" class="data row1 col1" >92.7</td>
#         <td id="T_d8adc19a_9866_11e7_81dd_a434d9ea9ddarow1_col2" class="data row1 col2" >0.0139</td>
#     </tr>    <tr>
#         <th id="T_d8adc19a_9866_11e7_81dd_a434d9ea9dda" class="row_heading level0 row2" >電子零組件業</th>
#         <td id="T_d8adc19a_9866_11e7_81dd_a434d9ea9ddarow2_col0" class="data row2 col0" >0.883</td>
#         <td id="T_d8adc19a_9866_11e7_81dd_a434d9ea9ddarow2_col1" class="data row2 col1" >84.8</td>
#         <td id="T_d8adc19a_9866_11e7_81dd_a434d9ea9ddarow2_col2" class="data row2 col2" >0.0104</td>
#     </tr>    <tr>
#         <th id="T_d8adc19a_9866_11e7_81dd_a434d9ea9dda" class="row_heading level0 row3" >電機機械</th>
#         <td id="T_d8adc19a_9866_11e7_81dd_a434d9ea9ddarow3_col0" class="data row3 col0" >1.46</td>
#         <td id="T_d8adc19a_9866_11e7_81dd_a434d9ea9ddarow3_col1" class="data row3 col1" >80</td>
#         <td id="T_d8adc19a_9866_11e7_81dd_a434d9ea9ddarow3_col2" class="data row3 col2" >0.0182</td>
#     </tr>    <tr>
#         <th id="T_d8adc19a_9866_11e7_81dd_a434d9ea9dda" class="row_heading level0 row4" >電腦及週邊設備業</th>
#         <td id="T_d8adc19a_9866_11e7_81dd_a434d9ea9ddarow4_col0" class="data row4 col0" >1</td>
#         <td id="T_d8adc19a_9866_11e7_81dd_a434d9ea9ddarow4_col1" class="data row4 col1" >58.3</td>
#         <td id="T_d8adc19a_9866_11e7_81dd_a434d9ea9ddarow4_col2" class="data row4 col2" >0.0172</td>
#     </tr>    <tr>
#         <th id="T_d8adc19a_9866_11e7_81dd_a434d9ea9dda" class="row_heading level0 row5" >其他電子業</th>
#         <td id="T_d8adc19a_9866_11e7_81dd_a434d9ea9ddarow5_col0" class="data row5 col0" >1.37</td>
#         <td id="T_d8adc19a_9866_11e7_81dd_a434d9ea9ddarow5_col1" class="data row5 col1" >48</td>
#         <td id="T_d8adc19a_9866_11e7_81dd_a434d9ea9ddarow5_col2" class="data row5 col2" >0.0286</td>
#     </tr>    <tr>
#         <th id="T_d8adc19a_9866_11e7_81dd_a434d9ea9dda" class="row_heading level0 row6" >汽車工業</th>
#         <td id="T_d8adc19a_9866_11e7_81dd_a434d9ea9ddarow6_col0" class="data row6 col0" >4.26</td>
#         <td id="T_d8adc19a_9866_11e7_81dd_a434d9ea9ddarow6_col1" class="data row6 col1" >34.1</td>
#         <td id="T_d8adc19a_9866_11e7_81dd_a434d9ea9ddarow6_col2" class="data row6 col2" >0.125</td>
#     </tr>    <tr>
#         <th id="T_d8adc19a_9866_11e7_81dd_a434d9ea9dda" class="row_heading level0 row7" >電子通路業</th>
#         <td id="T_d8adc19a_9866_11e7_81dd_a434d9ea9ddarow7_col0" class="data row7 col0" >1.4</td>
#         <td id="T_d8adc19a_9866_11e7_81dd_a434d9ea9ddarow7_col1" class="data row7 col1" >29.4</td>
#         <td id="T_d8adc19a_9866_11e7_81dd_a434d9ea9ddarow7_col2" class="data row7 col2" >0.0476</td>
#     </tr>    <tr>
#         <th id="T_d8adc19a_9866_11e7_81dd_a434d9ea9dda" class="row_heading level0 row8" >通信網路業</th>
#         <td id="T_d8adc19a_9866_11e7_81dd_a434d9ea9ddarow8_col0" class="data row8 col0" >0.743</td>
#         <td id="T_d8adc19a_9866_11e7_81dd_a434d9ea9ddarow8_col1" class="data row8 col1" >29</td>
#         <td id="T_d8adc19a_9866_11e7_81dd_a434d9ea9ddarow8_col2" class="data row8 col2" >0.0256</td>
#     </tr>    <tr>
#         <th id="T_d8adc19a_9866_11e7_81dd_a434d9ea9dda" class="row_heading level0 row9" >建材營造</th>
#         <td id="T_d8adc19a_9866_11e7_81dd_a434d9ea9ddarow9_col0" class="data row9 col0" >0.589</td>
#         <td id="T_d8adc19a_9866_11e7_81dd_a434d9ea9ddarow9_col1" class="data row9 col1" >28.9</td>
#         <td id="T_d8adc19a_9866_11e7_81dd_a434d9ea9ddarow9_col2" class="data row9 col2" >0.0204</td>
#     </tr>    <tr>
#         <th id="T_d8adc19a_9866_11e7_81dd_a434d9ea9dda" class="row_heading level0 row10" >塑膠工業</th>
#         <td id="T_d8adc19a_9866_11e7_81dd_a434d9ea9ddarow10_col0" class="data row10 col0" >1.13</td>
#         <td id="T_d8adc19a_9866_11e7_81dd_a434d9ea9ddarow10_col1" class="data row10 col1" >26</td>
#         <td id="T_d8adc19a_9866_11e7_81dd_a434d9ea9ddarow10_col2" class="data row10 col2" >0.0435</td>
#     </tr>    <tr>
#         <th id="T_d8adc19a_9866_11e7_81dd_a434d9ea9dda" class="row_heading level0 row11" >生技醫療業</th>
#         <td id="T_d8adc19a_9866_11e7_81dd_a434d9ea9ddarow11_col0" class="data row11 col0" >0.889</td>
#         <td id="T_d8adc19a_9866_11e7_81dd_a434d9ea9ddarow11_col1" class="data row11 col1" >25.8</td>
#         <td id="T_d8adc19a_9866_11e7_81dd_a434d9ea9ddarow11_col2" class="data row11 col2" >0.0345</td>
#     </tr>    <tr>
#         <th id="T_d8adc19a_9866_11e7_81dd_a434d9ea9dda" class="row_heading level0 row12" >貿易百貨</th>
#         <td id="T_d8adc19a_9866_11e7_81dd_a434d9ea9ddarow12_col0" class="data row12 col0" >1.26</td>
#         <td id="T_d8adc19a_9866_11e7_81dd_a434d9ea9ddarow12_col1" class="data row12 col1" >25.2</td>
#         <td id="T_d8adc19a_9866_11e7_81dd_a434d9ea9ddarow12_col2" class="data row12 col2" >0.05</td>
#     </tr>    <tr>
#         <th id="T_d8adc19a_9866_11e7_81dd_a434d9ea9dda" class="row_heading level0 row13" >觀光事業</th>
#         <td id="T_d8adc19a_9866_11e7_81dd_a434d9ea9ddarow13_col0" class="data row13 col0" >1.52</td>
#         <td id="T_d8adc19a_9866_11e7_81dd_a434d9ea9ddarow13_col1" class="data row13 col1" >24.4</td>
#         <td id="T_d8adc19a_9866_11e7_81dd_a434d9ea9ddarow13_col2" class="data row13 col2" >0.0625</td>
#     </tr>    <tr>
#         <th id="T_d8adc19a_9866_11e7_81dd_a434d9ea9dda" class="row_heading level0 row14" >化學工業</th>
#         <td id="T_d8adc19a_9866_11e7_81dd_a434d9ea9ddarow14_col0" class="data row14 col0" >0.823</td>
#         <td id="T_d8adc19a_9866_11e7_81dd_a434d9ea9ddarow14_col1" class="data row14 col1" >23.9</td>
#         <td id="T_d8adc19a_9866_11e7_81dd_a434d9ea9ddarow14_col2" class="data row14 col2" >0.0345</td>
#     </tr>    <tr>
#         <th id="T_d8adc19a_9866_11e7_81dd_a434d9ea9dda" class="row_heading level0 row15" >食品工業</th>
#         <td id="T_d8adc19a_9866_11e7_81dd_a434d9ea9ddarow15_col0" class="data row15 col0" >1.07</td>
#         <td id="T_d8adc19a_9866_11e7_81dd_a434d9ea9ddarow15_col1" class="data row15 col1" >23.5</td>
#         <td id="T_d8adc19a_9866_11e7_81dd_a434d9ea9ddarow15_col2" class="data row15 col2" >0.0455</td>
#     </tr>    <tr>
#         <th id="T_d8adc19a_9866_11e7_81dd_a434d9ea9dda" class="row_heading level0 row16" >鋼鐵工業</th>
#         <td id="T_d8adc19a_9866_11e7_81dd_a434d9ea9ddarow16_col0" class="data row16 col0" >0.625</td>
#         <td id="T_d8adc19a_9866_11e7_81dd_a434d9ea9ddarow16_col1" class="data row16 col1" >18.7</td>
#         <td id="T_d8adc19a_9866_11e7_81dd_a434d9ea9ddarow16_col2" class="

# %%
from bokeh.charts import Bar

# %%
p = Bar(dfDelOutl,label='Industry',values='Eps', legend=None, agg='mean',title='各產業別Eps平均值')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="112903cd-88c8-4491-ba3b-8c20f9ff32e6"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#112903cd-88c8-4491-ba3b-8c20f9ff32e6").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("112903cd-88c8-4491-ba3b-8c20f9ff32e6");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '112903cd-88c8-4491-ba3b-8c20f9ff32e6' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"d2ebb62b-b189-4c56-bf4b-bd5acfed7256":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"5386d76c-332d-4dfd-87e7-d8f66d20ecbf","type":"Rect"},{"attributes":{"overlay":{"id":"02888607-67d6-47cb-8d93-f44f45bfe408","type":"BoxAnnotation"},"plot":{"id":"bc0ae5a9-4940-4cb9-b0f3-f1809f6bda2b","subtype":"Chart","type":"Plot"}},"id":"31127822-70ab-4ac6-9f04-8d563cc5544c","type":"BoxZoomTool"},{"attributes":{"callback":null,"column_names":["y","label","line_color","height","color","x","width","line_alpha","fill_alpha"],"data":{"Industry":["\u98df\u54c1\u5de5\u696d"],"chart_index":[{"Industry":"\u98df\u54c1\u5de5\u696d"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[1.0668181818181817],"label":[{"Industry":"\u98df\u54c1\u5de5\u696d"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["\u98df\u54c1\u5de5\u696d"],"y":[0.5334090909090908]}},"id":"57bf0f38-6309-4cdd-b698-cd771d7b992a","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"293e6601-4a76-4b0d-aaa2-dfb2e615c75e","type":"Rect"},{"attributes":{"data_source":{"id":"48be3cd1-f0f7-4b90-8652-a34ca8a569b4","type":"ColumnDataSource"},"glyph":{"id":"6beb13af-77e4-40b4-9a3b-2f213708d54f","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"48598ab1-5137-4419-b286-1c8c83037257","type":"GlyphRenderer"},{"attributes":{"plot":null,"text":"\u5404\u7522\u696d\u5225Eps\u5e73\u5747\u503c"},"id":"87dbd003-777a-4385-b981-8806571c6952","type":"Title"},{"attributes":{"callback":null,"column_names":["y","label","line_color","height","color","x","width","line_alpha","fill_alpha"],"data":{"Industry":["\u5176\u4ed6"],"chart_index":[{"Industry":"\u5176\u4ed6"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[1.8460344827586213],"label":[{"Industry":"\u5176\u4ed6"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["\u5176\u4ed6"],"y":[0.9230172413793106]}},"id":"4ef95882-55bb-48e4-be76-a164ef78af8a","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ccba6029-fbbc-4e3b-ad43-ac43ffaf6e7a","type":"Rect"},{"attributes":{"data_source":{"id":"57bf0f38-6309-4cdd-b698-cd771d7b992a","type":"ColumnDataSource"},"glyph":{"id":"3db4d1d2-ebca-44d0-a7ef-0ce502aab5ac","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"395939ef-4b3f-4699-94b3-4e2f3b6ae2e5","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"d0a9489c-1e17-4e91-bb13-85cfbf9ba749","type":"ColumnDataSource"},"glyph":{"id":"86473d50-b5d9-4f07-8f1b-12f92e690dc2","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"e065f14c-a2dc-4b3b-a721-2ee5a90937f5","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"04a263ac-1f02-44c0-8e85-23b93f56e791","type":"Rect"},{"attributes":{"data_source":{"id":"179fb6a1-b4da-4bbf-acd0-09aad4a78ed8","type":"ColumnDataSource"},"glyph":{"id":"996ad8d9-4922-4ed1-9bba-bd59f402d67d","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"0057c4cc-830a-4721-b15e-c5a70f7790da","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"c ...

# %%
p3 = Bar(dfDelOutl,label='Industry',values='Eps', legend=None, agg='sum',color='Green',title='各產業內企業Eps總和')
show(p3)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="bb479e64-a62e-4d34-a892-9ee42bd9b90b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#bb479e64-a62e-4d34-a892-9ee42bd9b90b").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("bb479e64-a62e-4d34-a892-9ee42bd9b90b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'bb479e64-a62e-4d34-a892-9ee42bd9b90b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"10ca70b0-20d1-4b0a-b95a-4925fe1017f4":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["y","label","line_color","height","color","x","width","line_alpha","fill_alpha"],"data":{"Industry":["\u5316\u5b78\u5de5\u696d"],"chart_index":[{"Industry":"\u5316\u5b78\u5de5\u696d"}],"color":["Green"],"fill_alpha":[0.8],"height":[23.859999999999996],"label":[{"Industry":"\u5316\u5b78\u5de5\u696d"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["\u5316\u5b78\u5de5\u696d"],"y":[11.929999999999998]}},"id":"86db2a45-6aef-41c9-b447-0d2c32812d24","type":"ColumnDataSource"},{"attributes":{},"id":"bbb7053b-6859-4e16-97d7-db2d6bff42fc","type":"CategoricalTicker"},{"attributes":{"callback":null,"column_names":["y","label","line_color","height","color","x","width","line_alpha","fill_alpha"],"data":{"Industry":["\u8cbf\u6613\u767e\u8ca8"],"chart_index":[{"Industry":"\u8cbf\u6613\u767e\u8ca8"}],"color":["Green"],"fill_alpha":[0.8],"height":[25.189999999999998],"label":[{"Industry":"\u8cbf\u6613\u767e\u8ca8"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["\u8cbf\u6613\u767e\u8ca8"],"y":[12.594999999999999]}},"id":"f6402121-5b1e-4058-871c-fed79ebaea04","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["y","label","line_color","height","color","x","width","line_alpha","fill_alpha"],"data":{"Industry":["\u822a\u904b\u696d"],"chart_index":[{"Industry":"\u822a\u904b\u696d"}],"color":["Green"],"fill_alpha":[0.8],"height":[0.020000000000000018],"label":[{"Industry":"\u822a\u904b\u696d"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["\u822a\u904b\u696d"],"y":[0.010000000000000009]}},"id":"54740050-8f4e-4496-b623-77a02546a1d2","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"d0bc1032-7eaa-4bd4-86b9-ad39a19820f4","type":"ColumnDataSource"},"glyph":{"id":"243750b8-f9b4-4a49-a826-24cad7694a53","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"36fbe5e6-5e94-4120-a286-38b91f2a76be","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"fb7aaca6-1066-4dda-9843-c9092d685afe","type":"Rect"},{"attributes":{},"id":"7a249ac7-a30a-49a8-a9c7-e97913191642","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"30c8dce0-dbe3-41d4-81c6-4790c93741cb","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"591ebee7-6bce-457e-b1ba-5c388c0fc02c","type":"Rect"},{"attributes":{"data_source":{"id":"1f755cfa-f567-4542-ac52-7a9284d129b7","type":"ColumnDataSource"},"glyph":{"id":"444659d1-d17a-462e-a8af-7b57f91c7fc9","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"100a3d89-ba63-45c7-9bdc-595287a7efb6","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e50ba9f3-260d-4f2d-a063-5009d867e4da","type":"Rect"},{"attributes":{"callback":null,"column_names":["y","label","line_color","height","color","x","width","line_alpha","fill_alpha"],"data":{"Industry":["\u751f\u6280\u91ab\u7642\u696d"],"chart_index":[{"Industry":"\u751f\u6280\u91ab\u7642\u696d"}],"color":["Green"],"fill_alpha":[0.8],"height":[25.79],"label":[{"Industry":"\u751f\u6280\u91a ...

# %%
from bokeh.charts import Scatter
from bokeh.models import HoverTool

# %%
# Eps產業加總 對照 稅後淨利加總做比較
hover = HoverTool(tooltips=[
        ('Industry','@Industry')])

p2 = Scatter(IndsGroupEpsSum, x='Eps', y='NetProfitAfterTax', color='Industry', tools=['crosshair',hover,'save'], legend=None)
show(p2)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="8caa5560-d355-484e-872f-daa4dd111fbf"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#8caa5560-d355-484e-872f-daa4dd111fbf").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8caa5560-d355-484e-872f-daa4dd111fbf");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8caa5560-d355-484e-872f-daa4dd111fbf' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"cfd860e1-38bf-471c-9376-5951d22969bd":{"roots":{"references":[{"attributes":{"data_source":{"id":"5d838eb5-5c44-4abc-86bf-34d3d2e8fe3e","type":"ColumnDataSource"},"glyph":{"id":"1d73ef67-cfc8-4044-9a2d-b8d473e45a3f","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"4840112b-9e75-4cb5-843a-176a65ad7aa5","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#407ee7"},"line_color":{"value":"#407ee7"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"3876988f-cff5-4529-965f-152e8e7f7a9b","type":"Circle"},{"attributes":{"callback":null,"column_names":["y_values","x_values"],"data":{"Industry":["\u98df\u54c1\u5de5\u696d"],"chart_index":[{"Industry":"\u98df\u54c1\u5de5\u696d"}],"x_values":[23.47],"y_values":[19830634]}},"id":"c1ae7a11-ed25-4294-88e4-16b9ca4fb5ca","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["y_values","x_values"],"data":{"Industry":["\u5176\u4ed6\u96fb\u5b50\u696d"],"chart_index":[{"Industry":"\u5176\u4ed6\u96fb\u5b50\u696d"}],"x_values":[47.959999999999994],"y_values":[59544368]}},"id":"7950f0d5-f496-4814-ab4e-34d21117dad0","type":"ColumnDataSource"},{"attributes":{},"id":"e0577d5e-46c0-4975-a65a-6a474c20e322","type":"BasicTicker"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#df5320"},"line_color":{"value":"#df5320"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"af5a9449-7585-4486-8dcc-da1c9316b1e0","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"0e1b90d0-71b9-48a9-99e3-669120c6be93","type":"Circle"},{"attributes":{"data_source":{"id":"28f43ba9-363c-4d1c-9e9e-87f3e58f78ec","type":"ColumnDataSource"},"glyph":{"id":"de4bd53a-a4c3-4c2a-8f67-a722a4e4bf06","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"c47b944e-c9a6-435b-b4c9-b220f74381a8","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y_values","x_values"],"data":{"Industry":["\u91d1\u878d\u4fdd\u96aa\u696d"],"chart_index":[{"Industry":"\u91d1\u878d\u4fdd\u96aa\u696d"}],"x_values":[15.870000000000001],"y_values":[58312137]}},"id":"2cdd47ac-1583-4892-8935-5db481a9b2a1","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["y_values","x_values"],"data":{"Industry":["\u8cbf\u6613\u767e\u8ca8"],"chart_index":[{"Industry":"\u8cbf\u6613\u767e\u8ca8"}],"x_values":[25.189999999999998],"y_values":[13880183]}},"id":"5d838eb5-5c44-4abc-86bf-34d3d2e8fe3e","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["y_values","x_values"],"data":{"Industry":["\u6a61\u81a0\u5de5\u696d"],"chart_index":[{"Industry":"\u6a61\u81a0\u5de5\u696d"}],"x_values":[9.76],"y_values":[6168868]}},"id":"3eb3a863-f44b-4579-b3b4-402d9353cc78","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#df5320"},"line_color":{"value":"#df5320"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"d6a3421d-83d5-4803-a468-6b03cf7c23bf","type":"Circle"},{"attributes":{"data_source":{"id":"4ce75e08-27a0-47db-936c-9b9202784790","type":"ColumnDataSource"},"glyph":{"id":"6273f006-f8b0-4a3c-bd16-c7b557196046","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"81fc8bd3-6a54-4241-b4f3-a499272eb735","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y_values","x_values"],"data":{"Industry":["\u73bb\u7483\u9676\u74f7"],"chart_index":[{"Industry":"\u73bb\u7483\u9676\u74f7"}],"x_values":[1.3800000000000001],"y_values":[402539]}},"id":"b2544099-3ca7-49f7-81b3-78e3250f16d6","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["y_values","x_values"],"data": ...

# %%
#檢視前10大Eps加總的行業
IndsGroupEpsSum = IndsGroupEpsSum.sort_values(by='Eps', ascending=False)
IndsGroupEpsSum.head(10)
# Out:
#               Eps  OperationIncome  NetProfitAfterTax    Profit
# Industry
# 其他       107.0700        408058699           37258538   14.1765
# 半導體業      92.7000       1121309305          213421612    1.8589
# 電子零組件業    84.7600        643215801           28937392    1.8240
# 電機機械      80.0300        212609549           15073454    3.7005
# 電腦及週邊設備業  58.2700       2667716295           45473504   -5.9165
# 其他電子業     47.9600       2121122903           59544368    0.8928
# 汽車工業      34.1000        210624271           14769831    0.6448
# 電子通路業     29.3900        714259769           10893026    0.3027
# 通信網路業     28.9900        431256614           33908334    1.2683
# 建材營造      28.8700        117554303           12242161 -213.3516

# %%
from bokeh.models import Legend, LabelSet, Label

# %%
#Eps 各產業平均 對照 稅後淨利平均做比較
hover = HoverTool(tooltips=[
        ('Industry','@Industry'),
    ('Eps','@x_values'),
    ('Eps','@y_values')])

label1 = Label(x=1.2875, y= 2964189.0556,text='半導體產業',level='glyph',
                 x_offset=1, y_offset=5,render_mode='canvas')
label2 = Label(x=4.2625, y= 1846228.8750,text='汽車工業',level='glyph',
                 x_offset=1, y_offset=1)
label3 = Label(x=1.5100, y= 4574498.7500,text='油電燃氣業',level='glyph',
                 x_offset=1, y_offset=5,render_mode='canvas')
label4 = Label(x=1.1296, y= 3207761.3913,text='塑膠工業',level='glyph',
                 x_offset=1, y_offset=5,render_mode='canvas')
label5 = Label(x=0.7935, y= 2915606.8500,text='金融保險業',level='glyph',
                 x_offset=1, y_offset=5,render_mode='canvas')
label6 = Label(x=1.3703, y= 1701267.6571,text='其他電子業',level='glyph',
                 x_offset=1, y_offset=5,render_mode='canvas')


p2 = Scatter(IndsGroupEpsMean, x='Eps', y='NetProfitAfterTax', color='Industry', tools=['crosshair',hover,'save'],
            legend=None)

p2.add_layout(label1)
p2.add_layout(label2)
p2.add_layout(label3)
p2.add_layout(label4)
p2.add_layout(label5)
p2.add_layout(label6)

p2.x_range.end = 5

show(p2)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="fb9c7c13-0e22-4b04-81a5-c8c9b67fc524"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#fb9c7c13-0e22-4b04-81a5-c8c9b67fc524").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("fb9c7c13-0e22-4b04-81a5-c8c9b67fc524");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'fb9c7c13-0e22-4b04-81a5-c8c9b67fc524' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"5d34e2f5-fd0b-4ced-a9b3-c2e04400a29c":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#407ee7"},"line_color":{"value":"#407ee7"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"500e0bc2-d5bf-4ede-87f2-438f1baba11a","type":"Circle"},{"attributes":{},"id":"e10980e9-19c7-4814-9ba5-00fb652596c6","type":"ToolEvents"},{"attributes":{"callback":null,"end":5023897.845,"start":-368891.29500000004},"id":"ab36c3ac-1a59-4e7d-9de0-2744a54185c4","type":"Range1d"},{"attributes":{"data_source":{"id":"82a444bb-67a1-4e97-b8af-0e1c77d237d7","type":"ColumnDataSource"},"glyph":{"id":"848bccd9-05f0-4934-958c-1a60f32758c6","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"ffba4c76-a73c-4f3f-a4b9-36da2172d185","type":"GlyphRenderer"},{"attributes":{"level":"glyph","plot":{"id":"4dcbaa13-4c90-48ad-8e3d-7f2b876552a1","subtype":"Chart","type":"Plot"},"text":"\u6cb9\u96fb\u71c3\u6c23\u696d","x":1.51,"x_offset":1,"y":4574498.75,"y_offset":5},"id":"915882f5-aeaf-40f2-904a-447366aa09a2","type":"Label"},{"attributes":{"data_source":{"id":"32ed2efd-fc90-480c-90f9-46ab995243ec","type":"ColumnDataSource"},"glyph":{"id":"761e7847-0416-4bd2-a2d6-2e2c87f57897","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"3eb06d1c-2281-401c-8c46-8959cae9a414","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#5ab738"},"line_color":{"value":"#5ab738"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"89fec1b9-66e7-4dff-bada-601380a9ec23","type":"Circle"},{"attributes":{"axis_label":"NetProfitAfterTax","formatter":{"id":"d6c1b033-b8cd-4786-b017-2f1d110f833d","type":"BasicTickFormatter"},"plot":{"id":"4dcbaa13-4c90-48ad-8e3d-7f2b876552a1","subtype":"Chart","type":"Plot"},"ticker":{"id":"34a04d45-c111-4e71-ac76-b8ef577dce20","type":"BasicTicker"}},"id":"dd70e2df-c4d5-489a-977c-e084504b7aff","type":"LinearAxis"},{"attributes":{"plot":{"id":"4dcbaa13-4c90-48ad-8e3d-7f2b876552a1","subtype":"Chart","type":"Plot"}},"id":"fe274dd6-73b4-4ef1-b2d5-09d0cb252f31","type":"CrosshairTool"},{"attributes":{"data_source":{"id":"98e10a72-e846-4249-b646-63bb63a5e45e","type":"ColumnDataSource"},"glyph":{"id":"4123670c-fdb5-4b2a-86d7-2dc2e228a5fc","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"a37049aa-1291-4996-b9fb-dd3c4489c4f4","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y_values","x_values"],"data":{"Industry":["\u98df\u54c1\u5de5\u696d"],"chart_index":[{"Industry":"\u98df\u54c1\u5de5\u696d"}],"x_values":[1.0668181818181817],"y_values":[901392.4545454546]}},"id":"c764d825-4dd7-46f2-b47b-ec9f674d7e9a","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"00470363-ebad-42f6-8f1a-12eb914ffedf","type":"Circle"},{"attributes":{"data_source":{"id":"4416b58e-8d30-43f9-afe8-35933202cc90","type":"ColumnDataSource"},"glyph":{"id":"f5c35a70-424c-4d38-b6ef-e4e877de6fed","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"b7db1494-9ac2-4b8f-9a24-620184399c84","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y_values","x_values"],"data":{"Industry":["\u91d1\u878d\u4fdd\u96aa\u696d"],"chart_index":[{"Industry":"\u91d1\u878d\u4fdd\u96aa\u696d"}],"x_values":[0.7935000000000001],"y_values":[2915606.85]}},"id":"8906c72f-09f3-4855-90ae-88cf95b812f8","type":"ColumnDataSource"},{"attributes":{"dimension":1,"plot":{"id":"4dcbaa13-4c90-48ad-8e3d-7f2b876552a1","subtype":"Chart","type":"Plot"},"ticker":{"id":"34a04d45-c111-4e71-ac76-b8ef577dce20","type":"BasicTicker"}},"id":"f63d5749-d4d6-4a51-9422-6f0d6b6ffb55","type":"Grid"},{"attributes": ...

# %% [markdown]
# # 依照上述兩表，過濾出Eps門檻>1.4 或 稅後淨利>1500000的企業

# %%
IndsGroupEpsMean.loc[(IndsGroupEpsMean.Eps>1.4) | (IndsGroupEpsMean.NetProfitAfterTax>1500000)]
# Out:
#             Eps  OperationIncome  NetProfitAfterTax  Profit
# Industry
# 其他       1.8460   7,035,494.8103       642,388.5862  0.2444
# 其他電子業    1.3703  60,603,511.5143     1,701,267.6571  0.0255
# 半導體業     1.2875  15,573,740.3472     2,964,189.0556  0.0258
# 塑膠工業     1.1296  24,589,537.3913     3,207,761.3913  0.0834
# 汽車工業     4.2625  26,328,033.8750     1,846,228.8750  0.0806
# 油電燃氣業    1.5100  40,803,167.5000     4,574,498.7500  0.2110
# 觀光事業     1.5225   2,838,601.7500       201,424.8125  0.2124
# 金融保險業    0.7935  17,926,366.7500     2,915,606.8500  0.2923
# 電機機械     1.4551   3,865,628.1636       274,062.8000  0.0673

# %% [markdown]
# 交叉比較上面資訊，挑出以下產業別做進一步篩選：
#
# 選擇以下產業找標竿公司：
# 1. 行業中EPS加總之冠：其他
# 2. 行業平均EPS之冠：汽車工業
# 3. 平均稅後盈餘之冠：油電燃氣業
# 4. 產業稅後盈餘加總之冠：半導體業
# 5. 行業總營收之冠：電腦及週邊設備業
# 6. 稅後盈餘比例之冠：金融保險業

# %%
ChooseIndustry = ['其他','汽車工業','油電燃氣業','半導體業','電腦及週邊設備業','金融保險業']

# %%
#看上述5個產業Eps最高的企業為何, 與各自的Eps

for i in ChooseIndustry:
    dfChoose = df[df.Industry==i].sort_values(by='Eps',ascending=False)
    print('Industry:',i)
    print(dfChoose[['Company','Eps']].head(5))
    print('\n')
# Out:
# Industry: 其他
#            Company     Eps
# Code
# 3040    遠見科技股份有限公司 10.8200
# 8422     可寧衛股份有限公司  6.2800
# 8464  億豐綜合工業股份有限公司  6.0800
# 9941    裕融企業股份有限公司  4.1100
# 1262      綠悅控股有限公司  4.1000
#
#
# Industry: 汽車工業
#            Company     Eps
# Code
# 2227  裕隆日產汽車股份有限公司 10.9100
# 2207    和泰汽車股份有限公司  9.8300
# 2239  開曼英利工業股份有限公司  4.5200
# 1338      廣華控股有限公司  4.2900
# 2204  中華汽車工業股份有限公司  1.6700
#
#
# Industry: 油電燃氣業
#           Company    Eps
# Code
# 6505   台塑石化股份有限公司 3.6400
# 2616   山隆通運股份有限公司 3.3600
# 9937  全國加油站股份有限公司 0.9300
# 9931  欣高石油氣股份有限公司 0.9200
# 9926   新海瓦斯股份有限公司 0.9100
#
#
# Industry: 半導體業
#              Company     Eps
# Code
# 6415       矽力杰股份有限公司 10.2600
# 3413    京鼎精密科技股份有限公司  6.5800
# 2330  台灣積體電路製造股份有限公司  5.9400
# 2454      聯發科技股份有限公司  5.8000
# 2408      南亞科技股份有限公司  3.5500
#
#
# Industry: 電腦及週邊設備業
#          Company    Eps
# Code
# 2357  華碩電腦股份有限公司 7.6200
# 6414  樺漢科技股份有限公司 6.1700
# 2395    研華股份有限公司 4.2000
# 8114  振樺電子股份有限公司 3.3300
# 6579  研揚科技股份有限公司 2.9900
#
#
# Industry: 金融保險業
#              Company    Eps
# Code
# 2809    京城商業銀行股份有限公司 2.4000
# 2850    新光產物保險股份有限公司 1.8000
# 2867  三商美邦人壽保險股份有限公司 1.3300
# 2886    兆豐金融控股股份有限公司 1.0700
# 2851     中央再保險股份有限公司 1.0600
