# %%
#import library and set-up
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %pylab inline
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('precision',3)
pd.options.display.float_format = '{:,.4f}'.format
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#import data
path = 'C:/Users/AdamChang/Documents/Python Scripts/data/PFD Data/1060830 PE Ratio.csv'
df = pd.read_csv(path, encoding='big5hkscs', skiprows=2,index_col=0,
                names=['Code','Company','ROR','DYear','PER','PBR','Time'])

# %% [markdown]
# # 各Column名詞代稱
# ---
# * Code: 股市代號
# * Company: 公司名稱
# * ROR: 股票殖利率
# * DYear: 股利年度
# * PER: 本益比
# * PBR: 股價淨值比
# * Time: 財報年/季

# %%
#View the data summary
df.describe(include='all')
# Out:
#                Company      ROR    DYear  PER      PBR   Time
# count              894 894.0000 894.0000  894 894.0000    894
# unique             894      nan      nan  643      nan      2
# top     永新-KY               nan      nan    -      nan  106/2
# freq                 1      nan      nan  173      nan    884
# mean               NaN   3.5982 105.0000  NaN   1.9397    NaN
# std                NaN   2.8266   0.0000  NaN   3.8326    NaN
# min                NaN   0.0000 105.0000  NaN   0.3700    NaN
# 25%                NaN   1.0750 105.0000  NaN   0.8900    NaN
# 50%                NaN   3.6150 105.0000  NaN   1.2900    NaN
# 75%                NaN   5.5600 105.0000  NaN   2.0875    NaN
# max                NaN  14.6000 105.0000  NaN  80.0000    NaN

# %% [markdown]
# # 檢視資料的Summary
# ---
# * 對ROR來說，Mean與Mode接近，推估股市平均報酬約略3.6%左右
# * 對PBR來說，Mean=1.94, Mode=1.29，推估資料向左側集中，大部分股價淨值比偏高
# * PER需要清理資料後才能檢視其概況

# %% [markdown]
# # 資料清理
# 1. 刪除股利年分、財報年/季欄位
# 2. 將本益比欄位補0值, 清除為字串值的PER，並值定為float

# %%
#tidy data
del df['DYear']
del df['Time']

df['PER'] = df.PER.replace({'-':0})

for i in range(len(df['PER'])):
    if type(df['PER'].iloc[i]) == str:
        df['PER'].iloc[i] = df['PER'].iloc[i].replace(',','')
        
df['PER'] = df['PER'].astype(float)
# Out:
# C:\Users\AdamChang\Anaconda3\lib\site-packages\pandas\core\indexing.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %% [markdown]
# # 導入Bokeh Library

# %%
#import visualization library
from bokeh.charts import Histogram
from bokeh.io import output_notebook, show
from bokeh.models import HoverTool
from bokeh.layouts import column

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b6586ca8-4f1a-4928-8f3b-7c0e9e0ce452">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # 檢視各項資料的分佈狀況

# %%
#show ROR historgram
histROR = Histogram(df, values='ROR',title='ROR Historgram')
histPER = Histogram(df, values='PER',title='PER Historgram')
histPBR = Histogram(df, values='PBR', title='PBR Historgram')

show(column(histROR,histPER,histPBR))
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="775e1f21-33e8-4e0e-afbf-f0e23194cf88"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#775e1f21-33e8-4e0e-afbf-f0e23194cf88").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("775e1f21-33e8-4e0e-afbf-f0e23194cf88");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '775e1f21-33e8-4e0e-afbf-f0e23194cf88' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"860b0a1a-1938-4d7c-a087-a2090b7d3f25":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["label","fill_alpha","color","line_color","line_alpha","height","x","width","y"],"data":{"chart_index":["(1157.8, 1160.9]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(1157.8, 1160.9]"],"line_alpha":[1.0],"line_color":["black"],"width":[3.046875],"x":["1159.35"],"y":[0.0]}},"id":"aab4fd93-20fb-462d-a064-82bfedbc9977","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["label","fill_alpha","color","line_color","line_alpha","height","x","width","y"],"data":{"chart_index":["(2.9, 3.1]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[15.0],"label":["(2.9, 3.1]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.24806853582554522],"x":["3.0"],"y":[7.5]}},"id":"e1449832-835c-48d8-adce-a19cb8aafa5f","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"5e0ada20-340f-4089-b3a2-c29c903af577","type":"ColumnDataSource"},"glyph":{"id":"9f83b88c-ccc2-44f8-b1ba-40be2573eaf2","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"b2552994-0f83-4d58-9ae0-3f31d55a1fe5","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"c0cbf645-ec54-427c-a846-6ee5494a7608","type":"ColumnDataSource"},"glyph":{"id":"19ba2e06-8793-4f61-a509-d735365d2a89","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"956abc10-1bdf-4c92-a50f-d5829a4ef957","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["label","fill_alpha","color","line_color","line_alpha","height","x","width","y"],"data":{"chart_index":["(78.3, 78.5]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(78.3, 78.5]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.24806853582553856],"x":["78.4"],"y":[0.0]}},"id":"a6b2426e-ad51-4c1c-947d-da5ba6f9e94d","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["label","fill_alpha","color","line_color","line_alpha","height","x","width","y"],"data":{"chart_index":["(62.6, 62.9]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(62.6, 62.9]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.24806853582554567],"x":["62.75"],"y":[0.0]}},"id":"8048b665-82e9-4dac-9606-d55e03a83cec","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b6d3eee6-a1b7-4ab1-a339-49e91f69989f","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9f1119bb-ad5d-4d59-b225-311e98423007","type":"Rect"},{"attributes":{"data_source":{"id":"2e930d60-e2e2-4b77-a856-9045d5852d94","type":"ColumnDataSource"},"glyph":{"id":"ba8aa92d-eedb-4479-84df-444e03a0c89f","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"d3f4a036-c81c-46a5-9598-8b57b608d94d","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["label","fill_alpha","color","line_color","line_alpha","height","x","width","y"],"data":{"chart_index":["(1715.4, 1718.4]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(1715.4, 1718.4]"],"line_alpha":[1.0],"line_color":["black"],"width":[3.046875],"x":["1716.9"],"y":[0.0]}},"id":"e7c200fb-e8ab-4798-95f7-d46f28f57c6f","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["label","fill_alpha","color","line_color","line_alpha","height","x","width","y"],"data":{"chart_index":["(1377.2, 1380.2]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(1377.2, 1380.2]"],"line_alpha":[1.0],"line_color":["black"],"width":[3.046875],"x":["1378.7" ...

# %% [markdown]
# PER 和 PBR明顯有較大的Outliar, 以Scatter檢視其合理的資料範圍

# %%
from bokeh.charts import Scatter
from bokeh.models import ColumnDataSource

# %%
hover = HoverTool(tooltips=[
        ('PBR','@x_values'),
        ('PER','@y_values')
    ])
scatter = Scatter(df, x='PBR', y='PER', legend=None, title='PBR vs PER',tools=[hover,'save'],color='navy')
show(scatter)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="d4df0e64-492a-49b7-bc3a-325febdcbf34"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#d4df0e64-492a-49b7-bc3a-325febdcbf34").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d4df0e64-492a-49b7-bc3a-325febdcbf34");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd4df0e64-492a-49b7-bc3a-325febdcbf34' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"e6dd21b3-10bd-4ff5-81b2-105adbba713b":{"roots":{"references":[{"attributes":{},"id":"3642d213-875f-4a40-9c70-177d4c4c5e1c","type":"BasicTicker"},{"attributes":{"plot":null,"text":"PBR vs PER"},"id":"5969e411-d3fe-4344-b036-735c8714a5b5","type":"Title"},{"attributes":{},"id":"1ca89a3d-0991-43f8-8074-84ea513ef436","type":"ToolEvents"},{"attributes":{"plot":{"id":"4d534c88-d436-49e4-b09e-d735ba18276d","subtype":"Chart","type":"Plot"}},"id":"19e6dc8b-8514-4dd4-b6ba-47061c2f3b53","type":"SaveTool"},{"attributes":{"axis_label":"PER","formatter":{"id":"50e0780d-7ee1-4c54-8949-e07c7ca4e3ea","type":"BasicTickFormatter"},"plot":{"id":"4d534c88-d436-49e4-b09e-d735ba18276d","subtype":"Chart","type":"Plot"},"ticker":{"id":"f161c73f-b280-49de-8bbc-bec22a9d1166","type":"BasicTicker"}},"id":"4a79443c-3007-460e-bc95-a684354e900c","type":"LinearAxis"},{"attributes":{"callback":null,"end":87.963,"start":-7.593},"id":"e8c5897b-a9ce-4072-a779-44435baf75ab","type":"Range1d"},{"attributes":{"callback":null,"end":2145.0,"start":-195.0},"id":"d2fe0bfc-6148-4813-a36b-dfae4c321b59","type":"Range1d"},{"attributes":{},"id":"50e0780d-7ee1-4c54-8949-e07c7ca4e3ea","type":"BasicTickFormatter"},{"attributes":{"callback":null,"plot":{"id":"4d534c88-d436-49e4-b09e-d735ba18276d","subtype":"Chart","type":"Plot"},"tooltips":[["PBR","@x_values"],["PER","@y_values"]]},"id":"57d54430-0083-4b81-a657-fa6fc4076f09","type":"HoverTool"},{"attributes":{"axis_label":"PBR","formatter":{"id":"d1f63c3d-70cc-4640-b651-38df45109a31","type":"BasicTickFormatter"},"plot":{"id":"4d534c88-d436-49e4-b09e-d735ba18276d","subtype":"Chart","type":"Plot"},"ticker":{"id":"3642d213-875f-4a40-9c70-177d4c4c5e1c","type":"BasicTicker"}},"id":"efc30f66-d945-4845-aede-662fdbae4b8e","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["y_values","x_values"],"data":{"chart_index":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,n ...

# %% [markdown]
# ` Outliar 剔除條件:`
# * 篩選PBR < 14
# * 篩選PER < 20
#
# ` 篩選ROR:`
# * 篩選殖利率大於平均值3.6的公司

# %%
#Delete outliar & filter the ROR
df2 = df.loc[(df.PBR<14)&(df.PER<20)&(df.ROR>3.6)]

# %% [markdown]
# 檢視篩選後Data的分布狀況

# %%
sns.pairplot(df2)

# %% [markdown]
# 檢視篩選出的Data correlation

# %%
#View the correlation of data
dfCorr = df2.corr()
sns.heatmap(dfCorr,annot=True)

# %% [markdown]
# 再一次檢視資料Summary

# %%
df3RORSort = df2.sort_values(by='ROR',ascending=False)
df3RORSort.describe()
# Out:
#            ROR      PER      PBR
# count 361.0000 361.0000 361.0000
# mean    6.0676  12.5014   1.6422
# std     1.8345   4.1980   0.9116
# min     3.6100   0.0000   0.4500
# 25%     4.6400  10.7200   1.0200
# 50%     5.8400  12.6600   1.3800
# 75%     6.9700  15.2200   2.0700
# max    13.6200  19.9000   6.5000

# %% [markdown]
# # 檢視根據篩選條件，ROR前100間的公司

# %%
df3RORSort.head(100)
# Out:
#              Company     ROR     PER    PBR
# Code
# 3056  總太             13.6200  6.9800 0.8700
# 4984  科納-KY          13.4700 10.0900 0.9500
# 3040  遠見             13.1200  3.1800 1.2800
# 1463  強盛             12.9900  4.3300 1.8000
# 6235  華孚             12.2800  2.1500 1.2800
# 2404  漢唐             11.2400  9.1800 2.2200
# 2936   客思達-KY        10.9300  8.9900 0.9600
# 3679   新至陞           10.8800 10.1900 1.3900
# 1808  潤隆             10.8800 12.6600 2.6900
# 1310  台苯             10.6500  8.2900 1.6100
# 2597  潤弘             10.4400  7.6300 1.5300
# 2489  瑞軒             10.4300  0.0000 1.1000
# 2542   興富發           10.4200 15.3800 1.8600
# 6201   亞弘電           10.1400 11.8900 1.1900
# 2536  宏普             10.0700  0.0000 0.6300
# 2538  基泰              9.8500  0.0000 0.5900
# 2539   櫻花建            9.5600  7.7900 1.8000
# 1604  聲寶              9.3600 15.7400 1.0700
# 3550  聯穎              9.2900 13.8000 0.7300
# 2537   聯上發            9.2700  0.0000 0.6100
# 2501  國建              9.1500  7.3900 0.8700
# 6115  鎰勝              9.1300 13.3500 1.7300
# 2535   達欣工            9.0800  6.7200 0.7600
# 2488  漢平              9.0700  9.0600 1.7400
# 1442  名軒              9.0500  7.1400 1.0900
# 2548  華固              9.0300  6.0900 1.2600
# 4952  凌通              9.0000 12.0100 2.1600
# 2493  揚博              8.9700 10.6400 1.3600
# 3014  聯陽              8.9600 13.6800 1.4600
# 3305  昇貿              8.9100 19.6300 0.8600
# 6216  居易              8.8600 11.6900 1.8400
# 5534  長虹              8.8600  6.2700 1.6600
# 2227   裕日車            8.7800 13.6700 4.2500
# 2511  太子              8.7700 11.1800 0.8000
# 2546  根基              8.6500  7.0800 0.8300
# 2420  新巨              8.6300 10.9600 1.9800
# 6214  精誠              8.6200 10.0500 1.2200
# 6136   富爾特            8.4400 11.3900 0.9400
# 3028   增你強            8.3800 13.6600 0.8500
# 3338  泰碩              8.3300 12.0500 1.9300
# 6224  聚鼎              8.2600 12.6100 2.3900
# 1709  和益              8.2100 11.2200 1.2300
# 3450  聯鈞              8.2100 13.0000 3.3500
# 6189  豐藝              8.2100 14.3600 1.5300
# 4722   國精化            8.1400 10.5100 1.3500
# 2023  燁輝              8.1300  9.1100 0.7700
# 2397  友通              8.0500 14.3700 2.2200
# 2430  燦坤              8.0300 13.6100 0.9000
# 2471  資通              8.0000 11.0900 1.1700
# 9943   好樂迪            7.9700 12.0400 2.1200
# 8112  至上              7.9400  8.5400 1.7800
# 2419  仲琦              7.9400 12.7400 1.6200
# 1582  信錦              7.8400 10.9300 2.0900
# 2889   國票金            7.8100 12.2800 0.7700
# 1776  展宇              7.6900 14.8600 1.3000
# 4552  力達-KY           7.6200 10.9900 2.4100
# 6277  宏正              7.6000 12.4900 2.8300
# 3501  維熹              7.5900  9.8900 1.1800
# 1229  聯華              7.5800 10.9900 1.1100
# 2812   台中銀            7.4900  8.6600 0.7500
# 2450  神腦              7.4700 14.3300 2.4800
# 3596  智易              7.4600 11.5700 1.2100
# 8081  致新              7.4600 14.4700 1.5500
# 4532  瑞智              7.4500 13.6000 2.0700
# 8163  達方              7.4200 13.0800 0.9900
# 6442  光聖              7.4000 18.6600 1.4300
# 1704  榮化              7.3900  9.1000 1.3700
# 1558  伸興              7.3400 11.6700 1.9100
# 9924  福興              7.3200 11.1200 1.5200
# 2340  光磊              7.2600 11.0100 1.1800
# 2483  百容              7.2000 13.5700 0.8900
# 2414  精技              7.2000 12.2000 1.1900
# 2892   第一金            7.1800 12.8300 1.2500
# 3528  安馳              7.1800 13.4900 1.6500
# 6230  超眾              7.1800 13.9000 2.7600
# 2890   永豐金            7.1800 12.9900 0.7600
# 8466   美吉吉-KY         7.1600 12.6200 2.8000
# 2114   鑫永銓            7.1500 16.9700 2.3600
# 8070  長華              7.1400 11.0800 1.6900
# 2880   華南金            7.1400 14.2400 1.1100
# 2887   台新金            7.0900 12.7600 0.9200
# 3130   一零四            7.0700 17.4500 3.7200
# 8131   福懋科            7.0700 11.5000 1.2500
# 3090   日電貿            7.0700 10.7200 1.6100
# 4737  華廣              7.0600 18.8400 1.6800
# 2426  鼎元              7.0600 16.5800 1.1200
# 1724  台硝              7.0400 14.9500 0.9500
# 3706  神達              7.0300  9.1200 0.8600
# 3005  神基              7.0100 10.7800 1.9400
# 6128  上福              7.0000 11.9400 2.1600
# 3042  晶技              6.9700 11.6500 1.4300
# 6281   全國電            6.9400 14.4900 2.7700
# 4935  茂林-KY           6.9200 10.8600 0.9600
# 3209  全科              6.8800 16.6100 1.5700
# 2357  華碩              6.8800 11.0700 1.0600
# 6112  聚碩              6.8600 11.3400 1.4600
# 3015  全漢              6.8300 19.4200 0.5200
# 6142  友勁              6.8300  0.0000 0.7300
# 2108  南帝              6.8200 17.8900 1.5500
# 2476  鉅祥              6.8000 11.3100 1.0800
